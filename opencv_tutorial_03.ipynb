# %% [markdown]
# <a href="https://colab.research.google.com/github/silverstar0727/study-/blob/master/opencv_tutorial_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 이미지 합치기
# cv2.add(): Saturation연산을 수행
# 0보다 작으면 0, 255보다 크면 255
#
# np.add(): Modulo연산을 수행
# 256는 0, 257은 1로 표현 (잘 사용 x)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9d9ebbd8-30dd-48a8-8974-be8f06c00340" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d9ebbd8-30dd-48a8-8974-be8f06c00340">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving asdf.jpg to asdf.jpg

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-395251a1-bf71-48e7-a15f-d5ede4f3d18d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-395251a1-bf71-48e7-a15f-d5ede4f3d18d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Crop File.jpg to Crop File.jpg

# %%
import cv2
import matplotlib.pyplot as plt

image_1 = cv2.imread('asdf.jpg')
image_2 = cv2.imread('Crop File.jpg')

result = cv2.add(image_1, image_2)
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()

result = image_1 + image_2
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 임계점(threshold) 처리하기
# cv2.threshold(image, thresh, max_value, type): 임계값을 기준으로 흑백으로 구분
# * image: 처리할 gray scale의 이미지
# * thresh. 임계 값(전체 픽셀에 대해 적용됨)
# * max_value: 임계값을 넘었을 때 적용될 값
# * type: 임계점을 처리하는 방식
#  * THRESH_BINARY:임계값보다 크면 max_value, 작으면 0
#  * THRESH_BINARY_INV: 임계값보다 작으면 max_value, 크면 0
#  * THRESH_TRUNC: 임계값보다 크면 임계값, 작으면 그대로
#  * THRESH_TOZERO: 임계값보다 크면 그대로 작으면 0
#  * THRESH_TOZERO_INV: 임계값보다 크면 0, 작으면 그대로

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8f28af2c-cc0f-4415-8c5d-a49d041fc1d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f28af2c-cc0f-4415-8c5d-a49d041fc1d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving asdf.jpg to asdf (1).jpg

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('asdf.jpg', cv2.IMREAD_GRAYSCALE)

images = []
ret, thres1 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
ret, thres2 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY_INV)
ret, thres3 = cv2.threshold(image, 127, 255, cv2.THRESH_TRUNC)
ret, thres4 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO)
ret, thres5 = cv2.threshold(image, 127, 255, cv2.THRESH_TOZERO_INV)
images.append(thres1)
images.append(thres2)
images.append(thres3)
images.append(thres4)
images.append(thres5)

for i in images:
  plt.imshow(cv2.cvtColor(i, cv2.COLOR_GRAY2RGB))
  plt.show()

# %% [markdown]
# # 적응 임계점
# 여러개의 필터를 이용하여 처리
#
# cv2.adaptiveThreshold(image, max_value, adaptive_method, type, block_size, C): 전체 픽셀에 대한 적용 x
# * max_value: 임계값을 넘었을 때 적용할 값
# * adaptive_method: 임계 값을 결정하는 계산방법
#  * ADAPTIVE_THRESH_MEAN_C: 주변영역의 평균값으로 결정
#  * ADAPTIVE_THRESH_GAUSSIAN_C: 가우시안 필터를 적용
# * type: 임계점을 처리하는 방식
# * block_size: 임계점을 적용할 영역의 크기
# * C: 평균이나 가중평균에서 차감할 값

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-403b0ff6-925b-4acc-ae96-abbbaa32e03f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-403b0ff6-925b-4acc-ae96-abbbaa32e03f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving asdf.jpg to asdf (2).jpg

# %%
import cv2

image = cv2.imread('asdf.jpg', cv2.IMREAD_GRAYSCALE)

ret, thres1 = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
thres2 = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 3)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_GRAY2RGB))
plt.show()

plt.imshow(cv2.cvtColor(thres1, cv2.COLOR_GRAY2RGB))
plt.show()

plt.imshow(cv2.cvtColor(thres2, cv2.COLOR_GRAY2RGB))
plt.show()
