# %% [markdown]
# <a href="https://colab.research.google.com/github/silverstar0727/1day-1commit-challenge/blob/master/pandas_day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파일불러오기 & 정렬 & groupby
#
# ## pandas day8

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ee68f870-5650-4ca6-b0a5-4d52c509a885" name="files[]" multiple disabled />
#      <output id="result-ee68f870-5650-4ca6-b0a5-4d52c509a885">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#             id            type  fiberID  ...  modelMag_r  modelMag_i  modelMag_z
# 0            0             QSO      601  ...   21.364187   21.020605   21.147340
# 1            1             QSO      788  ...   20.753925   20.693389   20.512314
# 2            2             QSO      427  ...   16.641249   16.660177   16.688928
# 3            3             QSO      864  ...   19.889798   19.758113   19.552855
# 4            4  STAR_RED_DWARF      612  ...   21.475342   19.487330   18.375655
# ...        ...             ...      ...  ...         ...         ...         ...
# 199986  199986             QSO      568  ...   20.014046   20.061940   19.862513
# 199987  199987          GALAXY      362  ...   19.776321   18.990039   18.528306
# 199988  199988  STAR_RED_DWARF      146  ...   20.420524   18.443126   17.331724
# 199989  199989          GALAXY       85  ...   17.440331   17.193743   16.969854
# 199990  199990             QSO      964  ...   20.327396   20.217198   19.995023
#
# ...

# %%
# 정렬하기
train = train.sort_values(['psfMag_u'], ascending = False)

# %%
train
# Out:
#             id              type  ...    modelMag_i    modelMag_z
# 101377  101377            GALAXY  ...     18.217553 -20506.469074
# 18277    18277          STAR_BHB  ...  -6072.621418  -7699.686300
# 67227    67227  SERENDIPITY_BLUE  ...   3119.273573 -10711.510774
# 95547    95547               QSO  ...     18.368419     20.717813
# 113606  113606            GALAXY  ...     18.691361     23.300577
# ...        ...               ...  ...           ...           ...
# 187706  187706            GALAXY  ...  -4300.752129 -15376.009366
# 143592  143592           ROSAT_D  ...   4062.499371 -10311.948894
# 26683    26683  SERENDIPITY_BLUE  ... -13187.594059 -26050.710196
# 74089    74089          STAR_BHB  ...    420.211169 -12522.702972
# 139197  139197               QSO  ...     21.187048     21.092828
#
# [199991 rows x 23 columns]

# %%
# groupby로 type별 데이터 나열
q = train.groupby('type')
q.groups
# Out:
# {'GALAXY': Int64Index([101377, 113606, 147012, 125825, 136709, 162680, 186406,  34232,
#              158977,  68611,
#              ...
#              166253,  58826, 195803,  60866, 162936,  76863,  79028,  37735,
#               46896, 187706],
#             dtype='int64', length=37347),
#  'QSO': Int64Index([ 95547, 137063,  64472,  49412, 171266,  28445,  26186,  17693,
#               22387, 144113,
#              ...
#               80900, 148016,  76936, 186862,  93544,  67824,  53049, 158969,
#              172746, 139197],
#             dtype='int64', length=49680),
#  'REDDEN_STD': Int64Index([ 55097,  68391,  59560, 171503,  69404,  56777, 195163,  38164,
#               86531, 172974,
#              ...
#               53303, 154308, 146865, 134036,  45272,  42412, 154503, 178101,
#               85676,  80038],
#             dtype='int64', length=14618),
#  'ROSAT_D': Int64Index([126150, 136372,  27233, 188900,   2239,  78500,  64659, 151644,
# ...
